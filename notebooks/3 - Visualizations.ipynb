# %%
#import libraries
import os
import pandas as pd
import random
import numpy as np
import math
import scipy.stats as st
from statistics import stdev
from scipy.stats import ttest_ind_from_stats
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
get_ipython().run_line_magic('matplotlib', 'inline')
sns.set(color_codes=True)

# %%
 #Import a CSV File into Python using Pandas
#define working directory
#os.chdir("../datasets/stock_data/")
#read csv file 
AB_df = pd.read_csv("../Datasets/stock_data/AB.csv")

# %%
AB_df.shape
# Out:
# (30, 5)

# %%
AB_df.head()
# Out:
#          Date      Close        Low       High  Volume
# 0  2021-10-05  49.788300  49.256751  50.182036  155900
# 1  2021-10-06  49.276440  48.853170  49.680022  208700
# 2  2021-10-07  49.424088  49.394558  50.221410  214600
# 3  2021-10-08  49.906422  49.433935  50.556091  223600
# 4  2021-10-11  49.148472  49.148472  50.388748  230600

# %%
type(AB_df)
# Out:
# pandas.core.frame.DataFrame

# %%
from datetime import date, timedelta
current_date = date.today().isoformat()   
days_before = (date.today()-timedelta(days=30)).isoformat()
AB_df['Volume'].plot(label='AB',figsize=(16,8),title='Voulme')
plt.xlabel("date")
plt.ylabel("Volume")
plt.title("AB Stock Volume from "+ days_before +" to " + current_date )
plt.legend();

# %%
AB_df[['Close']].plot(label='AB',figsize=(16,8),title='ClosePrice')
plt.legend()
plt.xlabel("date")
plt.ylabel("$ price")
plt.title("AB Stock Price from "+ days_before +" to " + current_date )
# Out:
# Text(0.5, 1.0, 'AB Stock Price from 2021-10-16 to 2021-11-15')
